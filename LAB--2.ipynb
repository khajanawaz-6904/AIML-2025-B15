# %% [markdown]
# <a href="https://colab.research.google.com/github/khajanawaz-6904/AIML-2025-B15/blob/main/LAB--2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![bfs1.png](data:image/png;base64,...)

# %%
from queue import Queue
graph={0:[1,2,3],
       1:[0,2],
       2:[0,1,3,5],
       3:[0,2,4],
       4:[3,5,7],
       5:[2,4,6,7],
       6:[5,7],
       7:[]}
def bfs (graph,source):
  Q=Queue()
  visited_vertices = set()
  Q.put(source)
  visited_vertices.update({source})
  while not Q.empty():
    vertex =Q.get()
    print(vertex,end="-->")
    for u in graph[vertex]:
      if u not in visited_vertices:
        Q.put(u)
        visited_vertices.update({u})
print("Bfs traversal of graph with source 1 is:")
bfs(graph,1)
# Out:
# Bfs traversal of graph with source 1 is:
# 1-->0-->2-->3-->5-->4-->6-->7-->

# %% [markdown]
# ![WhatsApp Image 2024-08-19 at 14.42.35_d716bd16.jpg](data:image/jpeg;base64,...)

# %%
from types import NotImplementedType
graph1 = {
    'A' :['B','C','G'],
    'B' :['A'],
    'C' :['A','D','F'],
    'D' :['A','C','H','E'],
    'E' :['D','H','F'],
    'F' :['C','E'],
    'G' :['A','D','H'],
    'H' :['D','E','G'],
}
def dfs(graph,node,visited):
  if node not in visited:
    visited.append(node)
    for k in graph[node]:
      dfs(graph,k,visited)
  return visited
visited = dfs(graph1,'B',[])
print(visited)
# Out:
# ['B', 'A', 'C', 'D', 'H', 'E', 'F', 'G']
